# %% [markdown]
# # Título

# %% [markdown]
# **Listas**
#
# - Item 1
# - Item 2
# - Item 3

# %%
print("Ola mundo")
# Out:
# Ola mundo

# %%
a = 2

# %%
print(a)
print(b)
# Out:
# 2
# 5

# %%
b = 5

# %% [markdown]
# # Pandas

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/9.8 MB 6.0 MB/s eta 0:00:02
#    --- ------------------------------------ 0.8/9.8 MB 6.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/9.8 MB 1.6 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/9.8 MB 1.6 MB/s eta 0:00:06
#    -------- ------------------------------- 2.1/9.8 MB 1.9 MB/s eta 0:00:05
#    ------------ --------------------------- 3.1/9.8 MB 2.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.2/9.8 MB 2.9 MB/s eta 0:00:02
#    --------------------- ------------------ 5.2/9.8 MB 3.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.1/9.8 MB 3.7 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.8 MB 3.7 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
carros = {'modelo' : ['Mustang','Dodge Challenger','GTR','Mcllaren'],
         'ano' : [2008, 2016 , 2020, 2025],
        'valor' : [286000 , 300000 , 800000 , 15000000]
        
        }



df =pd.DataFrame(carros)
df
# Out:
#              modelo   ano     valor
# 0           Mustang  2008    286000
# 1  Dodge Challenger  2016    300000
# 2               GTR  2020    800000
# 3          Mcllaren  2025  15000000
